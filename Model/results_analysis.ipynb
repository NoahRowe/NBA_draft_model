# %%
import pandas as pd
import numpy as np

data = pd.read_pickle("results_1.df")

# %%
year = 2017
draft = data[data.Year==year]

# %%
draft
# Out:
#    overallPick   Tm              Player  Year     HEIGHT  HEIGHT_W_SHOES  \
# 0            1  PHI       markellefultz  2017 -13.354059       -0.757457
# 1            2  LAL           lonzoball  2017 -13.380335       -0.900258
# 2            3  BOS         jaysontatum  2017 -13.009589        0.287830
# 3            4  PHO         joshjackson  2017 -13.160990       -0.193023
# 4            5  SAC          deaaronfox  2017 -13.487593       -1.231518
# 5            6  ORL       jonathanisaac  2017 -12.789994        0.951880
# 6            7  MIN      laurimarkkanen  2017 -12.949500        0.480843
# 7            9  DAL         dennissmith  2017 -13.478278       -1.170137
# 8           10  SAC         zachcollins  2017 -12.608578        1.645770
# 9           11  CHO           malikmonk  2017 -13.280689       -0.525925
# 10          12  DET         lukekennard  2017 -13.221225       -0.491644
# 11          13  DEN     donovanmitchell  2017 -13.567503       -1.313726
# ...
